# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style><style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# ## Nombre quelconque de paramètres

# %% [markdown]
# **Exercice :** Ecrire une fonction `produit` qui renvoie le produit d'un nombre quelconque de réels.

# %%
def produit(*nombres):
    ...
    for ...
    

print(produit(2, -3, 5, 5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def produit(*nombres):
#     resultat = 1
#     for x in nombres:
#         resultat *= x
#     return resultat
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `moyenne` qui renvoie la moyenne d'un nombre quelconque de réels sans utiliser les fonctions `mean`, `sum` et `len`.

# %%
def moyenne(*nombres):
    ...

print(moyenne(10, 8, 15))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def moyenne(*nombres):
#     somme = 0
#     N = 0
#     for x in nombres :
#         somme += x
#         N += 1
#     return somme/N
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `compte_pairs` qui renvoie le nombre d’entiers pairs parmi un nombre quelconque d'entiers relatifs.

# %%
def compte_pairs(...):
    N_pairs = 0
    for ...
        if ...
            ...
    return ...
    

print(compte_pairs(2, 5, 6, -12, 11, 13, 5, 0))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def compte_pairs(*nombres):
#     N_pairs = 0
#     for n in nombres:
#         if n%2 == 0:
#             N_pairs += 1
#     return N_pairs
# </code></pre>
# </details>

# %% [markdown]
# ## Fonctions lambda

# %% [markdown]
# **Exercice :** Définir une fonction `cube` sous forme d'une fonction lambda.

# %%
cube = ...

print(cube(-5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>cube = lambda x: x**3
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `valeur` qui renvoie la moyenne des valeurs d'une fonction $f$ en deux réels $a$ et $b$. La tester ensuite à la fonction $x\mapsto -3x+1$ en $-2$ et $2,3$ et à la fonction $x\mapsto x^2+5x-2$  en 5 et $-1$. Ces deux fonctions ne doivent pas être dénommées.

# %%
def valeur(f, a, b):
    ...

print(valeur(...))
print(valeur(...))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def valeur(f, a, b):
#     return (f(a)+f(b))/2
#
# print(valeur(lambda x: -3*x+1, -2, 2))
# print(valeur(lambda x: x**2+5*x-2, 5, -1))
# </code></pre>
# </details>
