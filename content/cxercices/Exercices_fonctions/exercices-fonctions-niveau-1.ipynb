# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style><style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# ## Fonctions de base

# %% [markdown]
# **Exercice :** Ecrire une fonction `carre` qui renvoie le carré d'un réel $x$.

# %%
def carre(x):
    ...
    
print(carre(-5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def carre(x):
#     return x**2
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `double_puissance` qui renvoie $2x^n$, $x$ et $n$ étant entrés.

# %%
def double_puissance(x,n):
    ...

print(double_puissance(3,5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def double_puissance(x,n):
#     return x**n
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `f` qui à tout réel $x$ associe $f(x)=\sqrt{x^2+3}$.
#
# On importera au préalable la fonction `sqrt` *(racine carrée)*.

# %%
from math import sqrt
def f(x):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from math import sqrt
# def f(x):
#     return sqrt(x**2+3)
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :**  Ecrire une fonction `vitesse` qui renvoie la vitesse moyenne (en m/s) lorsque l'on parcourt une distance $d$ (en m) pendant une durée $t$ (en s).

# %%
def vitesse(d, t):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def vitesse(d, t):
#     return d*t
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `arrondi_racine` qui renvoie l'arrondi de $\sqrt{x}$ à deux chiffres après la virgule, $x$ étant un réel positif ou nul.
#
# On pourra utiliser l'instruction `round`, sachant que `round(a, n)`  renvoie l'arrondi  d'un réel $a$ à $n$ chiffres après la virgule.

# %%
from ...
def arrondi_racine(x):
    ...

print(arrondi_racine(2))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from math import sqrt
# def arrondi_racine(x):
#     return round(sqrt(x), 2)
# </code></pre>
# </details>

# %% [markdown]
# ## Fonctions en géométrie

# %% [markdown]
# **Exercice :** Ecrire une fonction renvoyant les coordonnées du milieu du segment $[AB]$, les coordonnées de $A$ et $B$ étant données.

# %%
def coord_milieu(xA, yA, xB, yB):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def coord_milieu(xA, yA, xB, yB):
#     return (xA + xB)/2, (yA + yB)/2
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `distance` qui renvoie la distance entre deux points $A$ et $B$ dont les coordonnées dans un repère orthonormé sont respectivement $(x_A~,~y_A)$ et $(x_B~,~y_B)$.

# %%
from ...
def distance(xA, yA, xB, yB):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from math import sqrt
# def distance(xA, yA, xB, yB):
#     return sqrt((xB-xA)**2+(yB-yA)**2)
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction qui renvoie l'aire d'un trapèze, les longueurs de ses bases ($b$ et $B$) ainsi que celle de sa hauteur ($h$) étant données.

# %%
def aire_trapeze(b, B, h):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def aire_trapeze(b, B, h):
#     return (b+B)*h/2
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction qui renvoie la circonférence d'un cercle, son rayon $r$ étant donné.

# %%
from math import pi

def circonference_cercle(r):
    ...

print(circonference_cercle(1))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def circonference_cercle(r):
#     return 2*pi*r
# </code></pre>
# </details>

# %% [markdown]
# ## Pourcentages

# %% [markdown]
# **Exercice :** Ecrire une fonction Python renvoyant le prix obtenu après une diminution d'un prix initial de $t$%.

# %%
def solde(prix_initial, t):
   ...

print(solde(150,20))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def solde(prix_initial, t):
#     return prix_initial * (1-t/100)
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction renvoyant le taux, exprimé en pourcentage, correspondant à un coefficient multiplicateur de $t$%. Le résultat renvoyé sera une chaîne de caractères. Par exemple :
# - Une entrée de 1.23 entraînera en retour la chaîne de caractère : "Augmentation de 23%".
# - Une entrée de 0.88 entraînera en retour la chaîne de caractère : "Diminution de 12%".
# - Une entrée de 1 entraînera en retour la chaîne de caractère : "Pas d'augmentation ni de diminution".

# %%
def pourcentage(CM):
    ...
    
    
print(pourcentage(1.23))
print(pourcentage(0.88))
print(pourcentage(1))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def pourcentage(CM):
#     taux = (CM - 1)*100
#     if taux > 0:
#         return f"Augmentation de {taux}%"
#     elif taux < 0:
#         return f"Diminution de {-taux}%"
#     else:
#         return "Pas d'augmentation ni de diminution"
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction Python renvoyant le taux d'augmentation réciproque d'une diminution de $t\%$.

# %%
def taux_rec(t):
    ...
    

def affiche_pourcentage(taux):
    "Affiche le résultat sous forme de pourcentage, la valeur comportant au plus 4 chiffres significatifs"
    return f"{100*taux:.4g}%"


# Le résultat attendu ici est 25%.
print(f"Le taux d'augmentation réciproque d'une diminution de 20% est de {affiche_pourcentage(taux_rec(20))}.")

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def taux_rec(t):
#     CM = 1 - t/100
#     CM_rec = 1/CM
#     return CM_rec-1
# </code></pre>
# </details>

# %% [markdown]
# **Exercice avancé :** Ecrire une fonction Python renvoyant le coefficient multiplicateur équivalent à l'application de taux successifs (positifs ou négatifs) de $t_1$%, $t_2$%, $t_3$%,... quelqu'en soit leur nombre.

# %%
def CM_equivalent(*taux_pourcentages):
    resultat = ...
    for ...
    

print(f"""Le coefficient multiplicateur équivalent à une diminution de 10% suivie d'une augmentation de 10%, 
d'une diminution de 20% et d'une augmentation de 20%, est de {CM_equivalent(-10, 10, -20, 20):g}""")

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def CM_equivalent(*taux_pourcentages):
#     resultat = 1
#     for t in taux_pourcentages:
#         resultat *= (1+t/100)
#     return resultat
# </code></pre>
# </details>

# %% [markdown]
# ## Un peu de hasard

# %% [markdown]
# **Exercice :** Ecrire une fonction Python simulant un lancer de dé (équilibré).

# %%
from random import randint

def lancer_de():
    ...

print(lancer_de())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from random import randint
#
# def lancer_de():
#     return randint(1,6)
# </code></pre>
# </details>
