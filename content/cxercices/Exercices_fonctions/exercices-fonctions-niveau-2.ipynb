# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style><style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# ## Fonctions et instructions conditionnelles

# %% [markdown]
# **Exercice :** Ecrire une fonction `racine_carree` qui renvoie la racine carrée d'un réel positif de $x$. Si $x$ n'est pas un réel positif ou nul, la fonction retourne le texte *"x ne prend pas une valeur convenable !"*.

# %%
...
def racine_carree(x):
    if ...:
        ...
    else:
        ...
    
print(racine_carree(4))
print(racine_carree(0))
print(racine_carree(-2))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from math import sqrt
#
# def racine_carree(x):
#     if x>= 0:
#         return sqrt(x)
#     else:
#         return "x ne prend pas une valeur convenable !"
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire des fonctions `maximum` et `minimum` qui renvoient respectivement le maximum et le minimum de deux réels $a$ et $b$.

# %%
def maximum(a, b):
    if ...
    
    
def minimum(a, b):
    if ...
    

print(maximum(5,12))
print(minimum(5,12))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def maximum(a, b):
#     if a >= b:
#         return a
#     else:
#         return b
#
# def minimum(a, b):
#     if a <= b:
#         return a
#     else:
#         return b
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction `signe` qui renvoie une chaîne de caractère correspond au signe d'un réel $x$ :
# - "positif" si $x>0$ ;
# - "négatif" si $x<0$ ;
# - "nul" si $x=0$.

# %%
def signe(x):
    ...
    
print(signe(2.5))
print(signe(0))
print(signe(-1.235))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def signe(x):
#     if x > 0:
#         return "positif"
#     elif x < 0:
#         return "négatif"
#     else:
#         return "nul"
# </code></pre>
# </details>

# %% [markdown]
# ## Un peu de hasard

# %% [markdown]
# **Exercice :** Ecrire une fonction Python simulant 200 lancers de dé (équilibré) et renvoyant la moyenne des résultats obtenus.

# %%
from random import randint

def lancers_de():
    somme = 0
    for ...

print(lancers_de())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from random import randint
#
# def lancers_de():
#     somme = 0
#     for _ in range(200):
#         somme = somme + randint(1, 6)
#     return somme/1000
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction Python simulant 1000 lancers d'une pièce (équilibrée) et renvoyant la fréquence d'apparition de &laquo; Pile &raquo;.

# %%
...

def lancers_piece():
    ...
        
print(lancers_piece())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>from random import randint
#
# def lancers_piece():
#     n_Pile = 0
#     for _ in range(1000):
#         n_Pile = n_Pile + randint(0,1)
#     return n_Pile/1000
# </code></pre>
#
# ou
#
# <pre><code>from random import randint
#
# def lancers_piece():
#     n_Pile = 0
#     for _ in range(1000):
#         n_Pile += randint(0,1)
#     return n_Pile/1000</code></pre>
# </details>
