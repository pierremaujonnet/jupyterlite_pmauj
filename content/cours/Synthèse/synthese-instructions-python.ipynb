# %% [markdown]
# <style>
#     /*.bloc{
#         display: flex;
#     }*/
#     .encadre{
#         display: inline-block;
#         border: 6px double;
#         color: #2b2b2b;
#         border-radius:1rem;
#         padding:1rem;
#         margin:1rem 2rem;
#         background:#ddd;
#     }
#     .encadre li{
#         margin: 1rem;
#     }
# </style>

# %% [markdown]
# ## Syntaxe élémentaire

# %% [markdown]
# - Le langage Python est **sensible à la casse et aux indentations**.
# - Les *fins d’instructions* sont marquées par un simple **retour à la ligne**.
# - Les **indentations** font partie de la syntaxe. Elles permettent de *définir les blocs* sans avoir à utiliser d’instruction de fin de bloc.
# - Pour obtenir des *fonctions plus avancées* en langage Python, il est nécessaire d’**importer des bibliothèques/modules** qui contiennent des instructions supplémentaires.
# - Les commentaires se font :
#     - sur une ligne : en utilisant le symbole `#` en début de ligne ;
#     - sur plusieurs lignes : encadrés par des symboles de multilignes `"""` `"""`.
# - Les docstrings (documentations de fonctions) se font :
#     - sur une ligne : encadrés par des symboles `"` `"`;
#     - sur plusieurs lignes : encadrés par des symboles de multilignes `"""` `"""`.

# %%
# Itialisation de la variable a
a = 10

# définition de la fonction f
def f(x):
    """
    Fonction qui à tout réel x,
    associe son cube
    """
    return x**3

# Affichage de f(a)
print(f(a))

# %% [markdown]
# ## Opérations entre nombres

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soient a et b deux nombres. Sous condition d’existence :
#     <ul>
#         <li><code>a + b</code> : <strong>somme</strong> de a et b</li>
#         <li><code>a - b</code> : <strong>différence</strong> de a et b</li>
#         <li><code>a * b</code> : <strong>produit</strong> de a par b</li>
#         <li><code>a ** b</code> : a <strong>puissance</strong>  b</li>
#         <li><code>a / b</code> : <strong>quotient</strong> de a par b</li>
#         <li><code>a // b</code> : <strong>quotient dans la division euclidienne</strong> de a par b</li>
#         <li><code>a % b</code> : <strong>reste dans la division euclidienne</strong> de a par b</li>
#     </ul>
# </div></div>

# %% [markdown]
# **Remarque :** On peut obtenir la racine carrée d'un réel positif $a$ par l'instruction `a**(1/2)`, sa racine cubique par l'instruction `a**(1/3)`, ...

# %% [markdown]
# ## Bibliothèques/modules importants

# %% [markdown]
# ### Syntaxe élémentaire

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soit `biblio` une bibliothèse/un module Python dont `el` est un objet.
#     <ul>
#         <li><code>import biblio</code> : importe la bibliothèque en gardant son nom propre.
#             <ul>
#                 <li>Appel de <code>el</code> : <code>biblio.el</code></li>
#                 <li>Tout élement de <code>biblio</code> peut être appelé.</li>
#             </ul>
#         </li>
#         <li><code>import biblio as b</code> : importe la bibliothèque en lui affectant le nom <code>b</code>.
#             <ul>
#                 <li>Appel de <code>el</code> : <code>b.el</code></li>
#                 <li>Tout élement de <code>biblio</code> peut être appelé.</li>
#             </ul>
#         </li>
#         <li><code>from biblio import el</code> : importe l'élément <code>el</code> de la bibliothèque uniquement.
#             <ul>
#                 <li>Appel de <code>el</code> : <code>el</code></li>
#                 <li>Aucun autre élement de <code>biblio</code> peut être appelé.</li>
#             </ul>
#         </li>
#         <li><code>from biblio import *</code> : importe tous les éléments de la bibliothèque.
#             <ul>
#                 <li>Appel de <code>el</code> : <code>el</code></li>
#                 <li>Tout élement de <code>biblio</code> peut être appelé.</li>
#             </ul>
#         </li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Module `math`

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>pi</code> : valeur approchée de $\pi$</li>
#         <li><code>e</code> : valeur approchée de $\text{e}$</li>
#         <li><code>sqrt</code> : fonction racine carrée</li>
#         <li><code>cos</code>, <code>sin</code>, <code>tan</code> : fonctions trigonométriques</li>
#         <li><code>acos</code>, <code>asin</code>, <code>atan</code> : fonctions trigonométriques réciproques</li>
#         <li><code>exp</code> : fonction exponentielle</li>
#         <li><code>log</code> : fonction logarithme népérien</li>
#         <li><code>log10</code> : fonction logarithme décimal</li>
#     </ul>
# </div></div>

# %%
# Importation de la constante pi
# ainsi que des fonctions cos, sin et sqrt
# du module math.
from math import pi, cos, sin, sqrt

def f(x):
    return sqrt(4 + cos(x)+sin(3*x+pi/5))

# %% [markdown]
# ### Module `random`

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     Soient $a$ et $b$ deux entiers naturels.
#     <ul>
#         <li><code>random()</code> : nombre décimal aléatoire entre 0 et 1 (exclus)</li>
#         <li><code>randint(a, b)</code> : nombre entier aléatoire entre $a$ et $b$ (inclus)</li>
#     </ul>
# </div></div>

# %% [markdown]
# ## Variables booléennes

# %% [markdown]
# ### Opérateurs de comparaison

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soient a et b deux nombres.
#     <ul>
#         <li><code>a == b</code> : a <strong>est égal à</strong> b</li>
#         <li><code>a != b</code> : a <strong>est différent de</strong> b</li>
#         <li><code>a &lt; b</code> : a <strong>est strictement inférieur à</strong> b</li>
#         <li><code>a &gt; b</code> : a <strong>est strictement supérieur à</strong> b</li>
#         <li><code>a &le; b</code> : a <strong>est inférieur ou égal à</strong> b</li>
#         <li><code>a &ge; b</code> : a <strong>est supérieur ou égal à</strong> b</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Opérations entre variables booléennes

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soient P et Q deux variables booléennes.
#     <ul>
#         <li><code>P and Q</code> : P <strong>et</strong> Q</li>
#         <li><code>P or Q</code> : P <strong>ou</strong> Q</li>
#         <li><code>not P</code> : <strong>négation de</strong> PQ</li>
#     </ul>
# </div></div>

# %% [markdown]
# ## Listes

# %% [markdown]
# ### Création et ajout d'éléments

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>liste = []</code> : <strong>crée</strong> une liste <strong>vide</strong></li>
#         <li><code>liste = [a, b, c, d, e]</code> : <strong>crée</strong> une liste <strong>composée des éléments</strong> a, b, c, d et e</li>
#         <li><code>liste[i]</code> : <strong>éléments numéro i</strong> de la liste <i>(le premier élément étant liste[0])</i></li>
#         <li><code>liste[i:j]</code> : <strong>sous-liste</strong> formée des éléments d’indices i à j-1</li>
#         <li><code>liste.copy()</code> : crée une <strong>copie &laquo;superficielle&raquo;</strong> de la liste</li>
#         <li><code>liste1+liste2</code> : <strong> nouvelle liste</strong> obtenue par <strong>ajout des éléments de liste2</strong> à la suite des éléments de liste1</li>
#         <li><code>liste1.extend(liste2)</code> :  <strong>ajout des éléments de liste2</strong> à la suite des éléments de liste1 <strong> dans liste1</strong></li>
#         <li><code>liste.append(a)</code> :  <strong>ajout de l'élément a</strong> à la suite des éléments de la liste <strong> dans la liste</strong></li>
#         <li><code>liste.insert(i, a)</code> :  <strong>ajout de l'élément a</strong> au niveau de l'indice i <strong> dans la liste</strong></li>
#
# </ul>
#
#
#
#
#
# </div></div>

# %% [markdown]
# ### Modification/supression d'éléments

# %% [markdown]
# <div class="bloc"><div class="encadre">
#    <ul>
#        <li><code>liste[i] = a</code> : <strong>remplace</strong> l’élément d’indice i par a</li>
#        <li><code>del liste[i]</code> : <strong>supprime</strong> l’élément numéro i de la liste</li>
#        <li><code>liste.remove(a)</code> : <strong>supprime la première occurrence</strong> de a dans la liste</li>
#        <li><code>liste.clear()</code> : <strong>supprime tous</strong> les éléments de la liste</li>
#        <li><code>liste.pop()</code> : <strong>supprime et renvoie le dernier élément</strong> de la liste</li>
#        <li><code>liste.pop(i)</code> : <strong>supprime et renvoie l’élément d’indice i</strong> de la liste</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Tri

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>liste.reverse()</code> : <strong> inverse l’ordre</strong>  des éléments de la liste </li>
#         <li><code>liste.sort()</code> : <strong>réordonne</strong> les éléments de la liste <strong>par ordre croissant, alphabétique, ...</strong></li>
#         <li><code>sorted(liste)</code> : crée une <strong>nouvelle liste ordonnée</strong> sans modifier la liste initiale</li>
#     </ul>
#
#
# </div></div>

# %% [markdown]
# ### Divers

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>len(liste)</code> : <strong>longueur/nombre d’éléments</strong> de la liste</li>
#         <li><code>sum(liste)</code> : <strong>somme des éléments</strong> de la liste</li>
#         <li><code>max(liste)</code> : <strong>plus grand élément</strong> de la liste</li>
#         <li><code>min(liste)</code> : <strong>plus petit élément</strong> de la liste</li>
#         <li><code>a in liste</code> : vaut <code>True</code> si <strong>a est un élément</strong> de de la liste, et <code>False</code> sinon</li>
#         <li><code>liste.index(a)</code> : donne <strong>l’indice de la première occurrence</strong> de a dans la liste</li>
#         <li><code>liste.count(a)</code> : donne <strong>le nombre d’apparitions</strong> de a dans la liste</li>
#     </ul>
# </div></div>

# %% [markdown]
# ## Numpy

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Import :
#     <ul>
#         <li><code>import numpy as np</code></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Tableaux et `dtype`

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soit A un tableau numpy, créé via <code>np.array(...)</code>.
#     <ul>
#         <li><code>A.dtype</code> : <strong>type numpy</strong> des éléments de A <i>(tous les éléments d'un même tableau ont le même type)</i></li>
#         <li><code>A.ndim</code> : <strong>nombre de dimensions</strong> de A</li>
#         <li><code>A.shape</code> : <strong>dimensions</strong> de A, sous forme de <i>tuple</i></li>
#         <li><code>A.size</code> : <strong>nombre total d'éléments</strong> de A</li>
#         <li><code>A.itemsize</code> : <strong>espace mémoire d'un élément</strong> de A, en octets <i>(en relation avec <code>A.dtype</code>)</i></li>
#         <li><code>A.nbytes</code> : <strong>espace mémoire total</strong> des données de A, en octets</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Tableaux particuliers

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>np.zeros(format)</code> : tableau <strong>composé uniquement de 0</strong></li>
#         <li><code>np.ones(format)</code> : tableau <strong>composé uniquement de 1</strong></li>
#         <li><code>np.full(format, element)</code> : tableau <strong>composé de la répétition d'un élément</strong></li>
#         <li><code>np.eye(n)</code> : <strong>matrice unité</strong> d'ordre n</li>
#         <li><code>np.indices(format)</code> : <strong>grilles des indices</strong></li>
#         <li><code>np.arange(debut, fin, pas)</code> : tableau à 1 dimension de valeurs <strong>régulièrement espacées d'un pas fixé</strong></li>
#         <li><code>np.linspace(debut, fin, nombre)</code> : tableau à 1 dimension d'<strong>un nombre fixé de valeurs régulièrement espacées</strong></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Éléments et slicing

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soit A un tableau numpy à 2 dimensions.
#     <ul>
#         <li><code>A[i,j]</code> : <strong>élément</strong> à l'intersection de la i+1-ième ligne et de la j+1-ième colonne <i>(indices numérotés à partir de 0)</i></li>
#         <li><code>A[i,:]</code> : <strong>i+1-ième ligne</strong> de A</li>
#         <li><code>A[:,j]</code> : <strong>j+1-ième colonne</strong> de A</li>
#         <li><code>A[i,:].copy()</code>/<code>A[:,j].copy()</code> : <strong>copie</strong> de la i+1-ième ligne/j+1-ième colonne</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Opérations

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soient A et B deux tableaux numpy de même dimension. Les opérations <code>+</code>, <code>-</code>, <code>*</code>, <code>**</code> et les fonctions usuelles s'appliquent <strong>élément par élément</strong> <i>(calcul vectorisé)</i>.
#     <ul>
#         <li><code>A + B</code>, <code>A - B</code>, <code>A * B</code>, <code>A ** n</code> : opérations élément par élément</li>
#         <li><code>np.sqrt</code>, <code>np.exp</code>, <code>np.log</code> : racine carrée, exponentielle, logarithme népérien</li>
#         <li><code>np.cos</code>, <code>np.sin</code> : fonctions trigonométriques</li>
#         <li><code>np.pi</code>, <code>np.e</code> : constantes $\pi$ et $\text{e}$</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Maximum, minimum, somme, moyenne, variance, écart-type

# %% [markdown]
# <div class="bloc"><div class="encadre" style="display:inline-block;border:6px double;color:#2b2b2b;border-radius:1rem;padding:1rem;margin:1rem 2rem;background:#ddd;">
# Soit A un tableau numpy.
#     <ul>
#         <li style="margin:1rem;"><code>A.max()</code>/<code>A.min()</code> : <strong>maximum/minimum</strong> de A</li>
#         <li style="margin:1rem;"><code>A.argmax()</code>/<code>A.argmin()</code> : <strong>indice du maximum/minimum</strong> de A <i>(tableau aplati)</i></li>
#         <li style="margin:1rem;"><code>A.sum()</code> : <strong>somme</strong> des éléments de A</li>
#         <li style="margin:1rem;"><code>A.mean()</code>, <code>A.var()</code>, <code>A.std()</code> : <strong>moyenne, variance, écart-type</strong> des éléments de A</li>
#         <li style="margin:1rem;"><code>A.max(axis=0)</code>, <code>A.sum(axis=1)</code>, ... : mêmes calculs <strong>selon une direction</strong> <i>(0 : par colonne, 1 : par ligne)</i></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Booléens

# %% [markdown]
# <div class="bloc"><div class="encadre" style="display:inline-block;border:6px double;color:#2b2b2b;border-radius:1rem;padding:1rem;margin:1rem 2rem;background:#ddd;">
# Soit A un tableau numpy.
#     <ul>
#         <li style="margin:1rem;"><code>A &gt; x</code> : tableau booléen indiquant <strong>quels éléments vérifient la condition</strong> <i>(idem pour <code>&lt;</code>, <code>&lt;=</code>, <code>&gt;=</code>, <code>==</code>, <code>!=</code>)</i></li>
#         <li style="margin:1rem;"><code>~</code>, <code>&amp;</code>, <code>|</code> : <strong>négation, et, ou</strong> entre tableaux booléens</li>
#         <li style="margin:1rem;"><code>A[A &gt; x]</code> : <strong>sous-tableau des éléments</strong> vérifiant la condition</li>
#         <li style="margin:1rem;"><code>A[A &gt; x] = v</code> : <strong>remplace par v</strong> les éléments vérifiant la condition</li>
#         <li style="margin:1rem;"><code>np.where(A &gt; x)</code> : indices vérifiant la condition, <strong>sous forme de tuple</strong></li>
#         <li style="margin:1rem;"><code>np.argwhere(A &gt; x)</code> : indices vérifiant la condition, <strong>sous forme de tableau</strong></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Nombres aléatoires

# %% [markdown]
# <div class="bloc"><div class="encadre" style="display:inline-block;border:6px double;color:#2b2b2b;border-radius:1rem;padding:1rem;margin:1rem 2rem;background:#ddd;">
#     <ul>
#         <li style="margin:1rem;"><code>np.random.rand()</code>/<code>np.random.rand(n)</code> : <strong>flottant(s) aléatoire(s)</strong> entre 0 et 1</li>
#         <li style="margin:1rem;"><code>np.random.randint(a, b)</code>/<code>np.random.randint(a, b, n)</code> : <strong>entier(s) aléatoire(s)</strong> entre a (inclus) et b (exclu)</li>
#         <li style="margin:1rem;"><code>np.random.choice(tab)</code>/<code>np.random.choice(tab, n)</code> : <strong>tirage(s) au hasard</strong> dans le tableau tab</li>
#         <li style="margin:1rem;"><code>np.random.shuffle(tab)</code> : <strong>mélange en place</strong> les éléments de tab</li>
#         <li style="margin:1rem;"><code>np.random.seed(graine)</code> : <strong>fixe la graine</strong> aléatoire</li>
#         <li style="margin:1rem;"><code>rng = np.random.default_rng(n)</code> puis <code>rng.random(n)</code>, <code>rng.integers(debut, fin, nbre)</code> : <strong>génération moderne</strong> recommandée</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Calcul matriciel

# %% [markdown]
# <div class="bloc"><div class="encadre" style="display:inline-block;border:6px double;color:#2b2b2b;border-radius:1rem;padding:1rem;margin:1rem 2rem;background:#ddd;">
# Soient A et B deux matrices numpy.
#     <ul>
#         <li style="margin:1rem;"><code>np.dot(A, B)</code>/<code>A.dot(B)</code> : <strong>produit matriciel</strong> de A et B <i>(sous condition d'existence)</i></li>
#         <li style="margin:1rem;"><code>A.T</code> : <strong>transposée</strong> de A</li>
#     </ul>
#     Le module <code>numpy.linalg</code> (importé usuellement <code>import numpy.linalg as alg</code>) fournit :
#     <ul>
#         <li style="margin:1rem;"><code>alg.matrix_power(A, n)</code> : <strong>matrice A puissance n</strong></li>
#         <li style="margin:1rem;"><code>alg.det(A)</code> : <strong>déterminant</strong> de A</li>
#         <li style="margin:1rem;"><code>alg.inv(A)</code> : <strong>inverse</strong> de A <i>(sous condition d'existence)</i></li>
#         <li style="margin:1rem;"><code>alg.solve(A, B)</code> : <strong>solution</strong> de l'équation AX = B <i>(sous condition d'existence)</i></li>
#     </ul>
# </div></div>

# %% [markdown]
# ## SymPy

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Import :
#     <ul>
#         <li><code>import sympy as sp</code></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Symboles et expressions symboliques

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Pour utiliser le calcul formel, il faut d'abord définir des <strong>variables symboliques</strong>, de deux façons possibles :
#     <ul>
#         <li><code>x, y = sp.symbols('x y')</code> : <strong>crée</strong> des symboles nommés x et y</li>
#         <li><code>from sympy.abc import x, y</code> : <strong>importe directement</strong> les symboles x et y</li>
#     </ul>
# Une <strong>expression symbolique</strong> se construit à partir de variables symboliques et des opérateurs usuels <i>(exemple : <code>expr = x**2 + 2*x + 1</code>)</i>.
#
# </div></div>

# %% [markdown]
# ### Constantes et fonctions mathématiques

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>sp.pi</code>, <code>sp.E</code>, <code>sp.I</code> : <strong>constantes</strong> $\pi$, e, i</li>
#         <li><code>sp.oo</code>/<code>-sp.oo</code> : <strong>+∞/-∞</strong></li>
#         <li><code>sp.sqrt</code>, <code>sp.cos</code>, ... : <strong>fonctions usuelles</strong></li>
#         <li><code>expr.evalf()</code>/<code>sp.N(expr, n)</code> : <strong>valeur approchée</strong> d'une expression <i>(les calculs sont exacts par défaut)</i></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Fractions

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>sp.S(a)/b</code>/<code>sp.Rational(a, b)</code> : <strong>fraction exacte</strong> a/b</li>
#         <li><code>sp.cancel(expr)</code> : <strong>simplifie</strong> une fraction rationnelle</li>
#         <li><code>sp.together(expr)</code> : met sous <strong>dénominateur commun</strong></li>
#         <li><code>sp.apart(expr)</code> : <strong>décompose en éléments simples</strong></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Substitution et simplification

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>expr.subs(x, valeur)</code> : <strong>substitue</strong> x par une valeur dans expr</li>
#         <li><code>sp.simplify(expr)</code> : <strong>simplifie</strong> expr</li>
#         <li><code>sp.factor(expr)</code> : <strong>factorise</strong> expr</li>
#         <li><code>sp.expand(expr)</code> : <strong>développe</strong> expr</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Dérivation, intégration, limites

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soit expr une expression symbolique dépendant de x.
#     <ul>
#         <li><code>sp.diff(expr, x)</code> : <strong>dérivée</strong> de expr par rapport à x</li>
#         <li><code>sp.diff(expr, x, n)</code> : <strong>dérivée n-ième</strong> de expr par rapport à x</li>
#         <li><code>sp.integrate(expr, x)</code> : <strong>primitive</strong> de expr par rapport à x</li>
#         <li><code>sp.integrate(expr, (x, a, b))</code> : <strong>intégrale</strong> de expr entre a et b</li>
#         <li><code>sp.limit(expr, x, a)</code> : <strong>limite</strong> de expr quand x tend vers a</li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Équations et équations différentielles

# %% [markdown]
# <div class="bloc"><div class="encadre">
#     <ul>
#         <li><code>sp.solve(sp.Eq(expr1, expr2), x)</code>/<code>sp.solve(expr, x)</code> : <strong>résout</strong> une équation <i>(expr = 0)</i></li>
#         <li><code>sp.solveset(expr, x, domain=sp.S.Reals)</code> : <strong>résout</strong> une équation sur un domaine donné</li>
#         <li><code>sp.solve((eq1, eq2), (x, y))</code> : <strong>résout un système</strong> d'équations</li>
#         <li><code>Y = sp.Function('Y')</code> puis <code>sp.dsolve(equation_diff)</code> : <strong>résout une équation différentielle</strong></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Matrices

# %% [markdown]
# <div class="bloc"><div class="encadre">
# Soient M et N deux matrices sympy, créées via <code>Matrix([[...], [...]])</code>.
#     <ul>
#         <li><code>M.transpose()</code> : <strong>transposée</strong> de M</li>
#         <li><code>M.det()</code> : <strong>déterminant</strong> de M</li>
#         <li><code>M.trace()</code> : <strong>trace</strong> de M</li>
#         <li><code>M.inv()</code> : <strong>inverse</strong> de M</li>
#         <li><code>M + N</code>, <code>M * N</code>, <code>k * M</code> : <strong>somme, produit matriciel, produit par un scalaire</strong></li>
#         <li><code>M.solve(b)</code> : <strong>résout</strong> le système Mx = b</li>
#         <li><code>zeros(n)</code>/<code>zeros(n, p)</code>, <code>eye(n)</code>, <code>ones(n, p)</code>, <code>sp.diag(*valeurs)</code> : <strong>matrices particulières</strong> <i>(nulle, identité, de 1, diagonale)</i></li>
#     </ul>
# </div></div>

# %% [markdown]
# ### Affichage

# %% [markdown]
# <div class="bloc"><div class="encadre">
# <code>sp.init_printing()</code> : active un <strong>affichage esthétique</strong> des expressions <i>(notation mathématique)</i>.
# </div></div>
