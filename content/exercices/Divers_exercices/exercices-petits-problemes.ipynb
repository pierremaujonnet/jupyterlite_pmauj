# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# **Exercice :** Utiliser dans chacun des cas suivants un programme pour répondre au problème posé.
# 1. Afficher les entiers de −100 à 100 (compris).

# %%
...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>for i in range(-100, 101):
#     print(i)
# </code></pre>
# </details>

# %% [markdown]
# 2. Afficher les entiers pairs de 1 à 100.

# %%
...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>for i in range(1, 51):
#     print(2*i)
# #
# # Variante
# for i in range(1, 101):
#     if i%2 == 0:
#         print(i)
# </code></pre>
# </details>

# %% [markdown]
# 3. Afficher les multiples de 3 compris entre 7 et 205.

# %%
...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>for i in range(7, 206):
#     if i%3 == 0:
#         print(i)
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire dans chacun des cas suivants une fonction permettant de répondre au problème posé.
# 1. Calculer la somme des carrés de 1 à $n$ où $n$ est un entier naturel non nul.

# %%
def somme(n):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def somme(n):
#     s = 0
#     for i in range(1, n+1):
#         s = s + i**2
#     return s
# </code></pre>
# </details>

# %% [markdown]
# 2. Compter le nombre de multiples de 7 entre 1 et 1000.

# %%
def multiples():
    ...


print(multiples())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def multiples():
#     nombre = 0
#     for i in range(1, 1001):
#         if i%7 == 0:
#             nombre += 1
#     return nombre
# #
# #Variante
# def multiples_var():
#     liste = [i for i in range(1, 1001) if i%7 == 0]
#     return len(liste)
#
# print(multiples())
# </code></pre>
# </details>

# %% [markdown]
# 3. Rechercher le plus petit entier naturel $n$ tel que la somme $1 + 2 + · · · + n > 5000$.

# %%
def seuil():
    ...
    
print(seuil())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def seuil():
#     n = 1
#     s = 1
#     while s <= 5000:
#         n += 1
#         s += n
#     return n
# </code></pre>
# </details>

# %% [markdown]
# 4. Déterminer si $n(n+1)$ est divisible par 5 ou 9, $n$ étant un entier relatif.

# %%
def divisible(n):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def divisible(n):
#     if n*(n+1)%5 == 0:
#         return True
#     if n*(n+1)%9 == 0:
#         return True
#     return False
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Utiliser dans chacun des cas suivants un programme pour répondre au problème posé.
# 1. On place 1000€ au taux annuel de 3%. Au bout de combien d’années le capital aura-t-il doublé ? triplé ?

# %%
def double():
    ...
    

def triple():
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def double():
#     c = 1000
#     n = 0
#     while c < 2000:
#         c *= 1.03
#         n += 1
#     return n
#
# def triple():
#     c = 1000
#     n = 0
#     while c < 3000:
#         c *= 1.03
#         n += 1
#     return n
# </code></pre>
# </details>

# %% [markdown]
# 2. Un volume d’eau de 2 litres s’évapore de 10% chaque heure. Au bout de combien d’heures restera-t-il moins de 0,5 litre ?

# %%
def nb_heures():
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def nb_heures():
#     volume = 2
#     n = 0
#     while volume >= 0.5:
#         volume *= 0.9
#         n += 1
#     return n
# </code></pre>
# </details>

# %% [markdown]
# 3. Une école accueille 85 élèves. Chaque année, l’effectif augmente de 2%. En combien d’années dépassera-t-elle 120 élèves ?

# %%
def nb_annees():
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def nb_annees():
#     N_eleves = 85
#     n = 0
#     while N_eleves <= 120:
#         N_eleves *= 1.02
#         n += 1
#     return n
# </code></pre>
# </details>

# %% [markdown]
# 4. Une classe lit un roman de 150 pages. Les élèves lisent 12 pages par jour. Au bout de combien de jours auront-ils terminé ?

# %%
def nb_jours():
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def nb_jours():
#     n_pages = 150
#     n_j = 0
#     while n_pages > 0:
#         n_pages -= 12
#         n_j += 1
#     return n_j
# </code></pre>
# </details>

# %% [markdown]
# 5. Une classe organise une sortie scolaire. Chaque élève paie 8,50€. Le bus coûte 240€. À partir de combien d’élèves la sortie devient-elle rentable ?

# %%
def n_eleves():
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def n_eleves():
#     n_e = 0
#     prix_restant = 240
#     while prix_restant > 0:
#         prix_restant -= 8.5
#         n_e +=1
#     return n_e
# </code></pre>
# </details>
