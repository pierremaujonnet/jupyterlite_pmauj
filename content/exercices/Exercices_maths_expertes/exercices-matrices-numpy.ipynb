# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# ***Utiliser le module numpy afin de résoudre les exercices suivants.***

# %% [markdown]
# **Exercice :** On considère les matrices $A=\left(\begin{array}{ccccc}5&3&1\\1&0&-3\\7&-5&1\\\end{array}\right)$ et $B=\left(\begin{array}{ccccc}0&2&-3\\2&1&-2\\0&4&-3\\\end{array}\right)$.
# 1. Entrer $A$ et $B$ sous forme de tableaux numpy.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>import numpy as np
# A = np.array([[5,3,1],[1,0,-3],[7,-5,1]])
# B = np.array([[0,2,-3],[2,1,-2],[0,4,-3]])
# </code></pre>
# </details>

# %% [markdown]
# 2. Calculer les matrices $A+5B$ et $A^t-3Id_3$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(A+5*B)
# print(A.T-3*np.eye(3))
# </code></pre>
# </details>

# %% [markdown]
# 3. Calculer $A\times B$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(A.dot(B))
# </code></pre>
# </details>

# %% [markdown]
# 4. Calculer $A^5$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>import numpy.linalg as alg
# print(alg.matrix_power(A, 5))
# </code></pre>
# </details>

# %% [markdown]
# 5. Calculer le déterminant de $A$. $A$ est-elle inversible ? Si oui, calculer $A^{-1}$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(alg.det(A))
# print(alg.inv(A))
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :**
# 1. Résoudre le système $\left\{\begin{array}{l}3x-y+4z=35,7\\2x+5y-2z=20,9\\4x+3y+9z=98,2\\\end{array}\right.$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(alg.solve([[3,-1,4],[2,5,-2],[4,3,9]],[[35.7],[20.9],[98.2]]))
# </code></pre>
# </details>

# %% [markdown]
# 2. Résoudre le système $\left\{\begin{array}{l}6x+8y+z+2t=-8\\x+4y+6z-t=40\\3x+8y-z+3t=-32\\-6x+3y+8z+7t=29\\\end{array}\right.$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(alg.solve([[6,8,1,2],[1,4,6,-1],[3,8,-1,3],[-6,3,8,7]],[[-8],[40],[-32],[29]]))
# </code></pre>
# </details>

# %% [markdown]
# 3. Déterminer une fonction du second degré dont la courbe représentative dans un repère passe par les points $A(-1,3)$, $B(3,7)$ et $C(4,18)$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>print(alg.solve([[1,-1,1],[9,3,1],[16,4,1]],[[3],[7],[18]]))
# </code></pre>
# </details>

# %% [markdown]
# 4. Conjecturer l'expression des coefficients de $M^n$  en fonction de $n$, avec : $M=\left(\begin{array}{ccccc}1&0&0\\1&1&0\\1&1&1\\\\\end{array}\right)$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>M = np.array([[1,0,0],[1,1,0],[1,1,1]])
# for i in range(6):
#     print(f"n = {i} - M^n = {alg.matrix_power(M,i)}")
# </code></pre>
# </details>

# %% [markdown]
# 5. Les suites $(u_n)$ et $(v_n)$ sont définies par $\left\{\begin{array}{l}u_0=1\\v_0=1\\u_{n+1}=2u_n+3v_n\\v_{n+1}=u_n+v_n\\\end{array}\right.$.
# 		Calculer $u_1$, $v_1$, $u_2$, $v_2$, $u_{100}$ et $v_{100}$.

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>U = np.array([[1],[1]])
# A = np.array([[2,3],[1,1]])
# print(A.dot(U))
# print(alg.matrix_power(A,2).dot(U))
# print(alg.matrix_power(A,100).dot(U))
# </code></pre>
# </details>
