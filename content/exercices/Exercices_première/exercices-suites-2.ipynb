# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# **Exercice :**
#
# On considère :
# - la suite $(t_n)_{n\geq5}$ définie par $t_n=\sqrt{2n-9}$ ;
# - la suite $(u_n)_{n\geq0}$ définie par $u_n=\dfrac{-3n+1}{n+5}$ ;
# - la suite $(v_n)_{n\geq0}$ définie par $v_0=1$ et $v_{n+1}=\sqrt{v_n^2+3}$ ;
# - la suite $(w_n)$ arithmétique de premier terme $w_0=15$ et de raison $-\dfrac{3}{2}$.
#
#
# Ecrire des fonctions Python afin de résoudre les problèmes suivants.
# 1. Un entier naturel $n$ étant donné, déterminer $t_n$, $u_n$, $v_n$ et $w_n$.

# %%
from math import sqrt

def t(n):
    ...
    

def u(n):
    ...
    

def v(n):
    ...
    
    
def w(n):
    ...
    

print(t(7))
print(u(5))
print(v(6))
print(w(4))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>from math import sqrt
# #
# def t(n):
#     return sqrt(2*n-9)
# #
# def u(n):
#     return (-3*n+1)/(n+5)
# #
# def v(n):
#     k = 0
#     resultat = 1
#     while k &lt; n:
#         resultat = sqrt(resultat**2+3)
#         k += 1
#     return resultat
# #
# # Variante 1
# def v2(n):
#     resultat = 1
#     while n > 0:
#         resultat = sqrt(resultat**2+3)
#         n  -= 1
#     return resultat
# #
# # Variante 2 -> récursive
# def v_rec(n):
#     if n == 0:
#         return 1
#     else:
#         return sqrt(v_rec(n-1)**2+3)
# #
# def w(n):
#     return 15*(-3/2)**n
# #
# # Variante
# def w2(n):
#     resultat = 15
#     while n > 0:
#         resultat *= -3/2
#         n -= 1
#     return resultat
# </code></pre>
# </details>

# %% [markdown]
# 2. Déterminer une liste contenant les $n+1$ premiers termes des suites $(t_n)$ et $(v_n)$.

# %%
...

def liste_t(n):
    liste = []
    ...
    

def liste_v(n):
    ...
    

print(liste_t(5))
print(liste_v(5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>from math import sqrt
# #
# def liste_t(n):
#     liste = []
#     for i in range(5, n+6):
#         liste.append(sqrt(2*i-9))
#     return liste
# #
# # Variante : compréhension de liste
# def liste_t_variante(n):
#     return [sqrt(2*i-9) for i in range(5, n+6)]
# #
# def liste_v(n):
#     v = 1
#     liste = [v]
#     for _ in range(n):
#         v = sqrt(v**2+3)
#         liste.append(v)
#     return liste
# </code></pre>
# </details>

# %% [markdown]
# 3. Déterminer la somme des $n+1$ premiers termes des suites $(v_n)$ et $(w_n)$.

# %%
...

def somme_v(n):
    ...
    

def somme_w(n):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>from math import sqrt
# #
# def somme_v(n):
#     v = 1
#     somme = v
#     for _ in range(n):
#         v = sqrt(v**2+3)
#         somme += v
#     return somme
# #
# def somme_w(n):
#     w = 15
#     somme = v
#     for _ in range(n):
#         w *= -3/2
#         somme += w
#     return somme
# </code></pre>
# </details>

# %% [markdown]
# 4. Représenter graphiquement les suites $(u_n)$ et $(v_n)$.

# %%
import matplotlib.pyplot as plt
from math import sqrt

# Représentation des n premiers termes de (u_n) sous forme de nuages de points
def repr_u(n):
    x = list(range(n))
    y = ...
    plt.scatter(..., ..., marker="o", color="red")
    
# Représentation des n premiers termes de (v_n) sous forme de nuages de points
def repr_v(n):
    x = ...
    v = ...
    y = [v]
    for i in ...:
        v = ...
        y.append(v)
    ...
    
plt.clf()
repr_u(10)
repr_v(10)
plt.show()

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>import matplotlib.pyplot as plt
# from math import sqrt
# #
# # Représentation des n premiers termes de (u_n) sous forme de nuages de points
# def repr_u(n):
#     x = list(range(n))
#     y = [(-3*i+1)/(i+5) for i in range(n)]
#     plt.scatter(x, y, marker="o", color="red")
# #
# def repr_v(n):
#     x = list(range(n))
#     v = 1
#     y = [v]
#     for i in range(n-1):
#         v = sqrt(v**2+3)
#         y.append(v)
#     plt.scatter(x,y, marker="x", color="navy")
# #
# plt.clf()
# repr_u(10)
# repr_v(10)
# plt.show()
# </code></pre>
# </details>

# %% [markdown]
# 5. Déterminer une liste contenant les termes de la suite $(t_n)$ allant de $t_{10}$ à $t_{80}$ compris.

# %%
...

def liste_t_10_80():
    ...
    

print(liste_t_10_80())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>from math import sqrt
# #
# def liste_t_10_80():
#     return [sqrt(2*n-9) for n in range(10, 81)]
# </code></pre>
# </details>

# %% [markdown]
# 6. Déterminer le plus petit entier naturel $n$ tel que $v_n\geq60$.

# %%
...

def seuil_v():
    v = 1
    n = 0
    while ...

print(seuil_v())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>from math import sqrt
# #
# def seuil_v():
#     v = 1
#     n = 0
#     while v < 60:
#         v = sqrt(v**2+3)
#         n += 1
#     return n
# </code></pre>
# </details>

# %% [markdown]
# 7. Déterminer le plus petit entier naturel $n$ tel que $u_n<-2,95$.

# %%
def seuil_u():
    ...
    

print(seuil_u())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
# <pre><code>def seuil_u():
#     n = 0
#     while (-3*n+1)/(n+5) >= -2.95:
#         n += 1
#     return n
# </code></pre>
# </details>
