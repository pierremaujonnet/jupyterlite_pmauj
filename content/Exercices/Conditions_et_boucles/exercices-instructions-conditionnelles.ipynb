# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# **Exercice :** Ecrire une fonction renvoyant le nombre de solutions de l'équation $x^2=a$ selon la valeur de $a$.

# %%
def nb_solutions(a):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def nb_solutions(a):
#     if a > 0:
#         return 2
#     elif a == 0:
#         return 1
#     else:
#         return 0
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Le prix d'une place de cinéma dépend de l'âge du spectateur.
# - 5€ pour les moins de 18 ans ;
# - 7€ pour les 60 ans et plus ;
# - 8€ pour les autres.
# Compléter la fonction suivante.

# %%
def prix(age):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def prix(age):
#     if age < 18:
#         return 5
#     elif age >= 60:
#         return 7
#     else:
#         return 8
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Compléter la fonction suivante.

# %%
def parite(a, b):
    if a%2 == 0 ... b%2 == 0 :
        print("a et b sont tous les deux pairs.")
    elif a%2 == 0 ... b%2 == 0 :
        print("Parmi a et b, un seul entier est pair.")

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def parite(a, b):
#     if a%2 == 0 and b%2 == 0 :
#         print("a et b sont tous les deux pairs.")
#     elif a%2 == 0 or b%2 == 0 :
#         print("Parmi a et b, un seul entier est pair.")
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Compléter la fonction suivante de deux manières différentes.

# %%
def parite2(a, b):
    if a%2 == 0 ... b%2 == 0 :
        print("a et b sont tous les deux pairs.")
    ...
        print("Parmi a et b, au moins un entier est pair.")

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def parite2(a, b):
#     if a%2 == 0 and b%2 == 0 :
#         print("a et b sont tous les deux pairs.")
#     if a%2 == 0 or b%2 == 0 :
#         print("Parmi a et b, au moins un entier est pair.")
#
# def parite2(a, b):
#     if a%2 == 0 and b%2 == 0 :
#         print("a et b sont tous les deux pairs.")
#     if not (a%2 != 0 and b%2 != 0) :
#         print("Parmi a et b, au moins un entier est pair.")
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire une fonction permettant de déterminer si un triangle $ABC$ est rectangle lorsque l'on connaît les coordonnées des points $A$, $B$ et $C$.

# %%
def est_rectangle(xA, yA, xB, yB, xC, yC):
    ...

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def est_rectangle(xA, yA, xB, yB, xC, yC):
#     a2 = (xC-xB)**2+(yC-yB)**2
#     b2 = (xC-xA)**2+(yC-yA)**2
#     c2 = (xB-xA)**2+(yB-yA)**2
#     if a2 == b2:
#         return "Le triangle ABC est rectangle en C."
#     elif a2 == c2:
#         return "Le triangle ABC est rectangle en B."
#     elif b2 == c2:
#         return "Le triangle ABC est rectangle en A."
#     else:
#         return "Le triangle ABC n'est pas rectangle."
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Ecrire un programme permettant de connaître la nature éventuelle d’un quadrilatère $ABCD$ (parallélogramme, losange,
# rectangle, carré) dont les coordonnées des sommets sont données.

# %%
def nature_quadrilatere(xA, yA, xB, yB, xC, yC, xD, yD):
    if xA + xC == xB + xD ... yA + yC == yB + yD:
        ...
        if ... ... ...:
            return "ABCD est un carré."
        elif ... ... ...:
            return "ABCD est un losange."
        elif ... ... ...:
            return "ABCD est un rectangle."
        else:
            return ...
    else:
        return "ABCD n'est pas un parallélogramme."

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def nature_quadrilatere(xA, yA, xB, yB, xC, yC, xD, yD):
#     if xA + xC == xB + xD and yA + yC == yB + yD:
#         AB2 = (xB-xA)**2+(yB-yA)**2
#         AC2 = (xC-xA)**2+(yC-yA)**2
#         BC2 = (xC-xB)**2+(yC-yB)**2
#         if AB2 == BC2 and AC2 == AB2 + BC2:
#             return "ABCD est un carré."
#         elif AB2 == BC2 and AC2 != AB2 + BC2:
#             return "ABCD est un losange."
#         elif AB2 != BC2 and AC2 == AB2 + BC2:
#             return "ABCD est un rectangle."
#         else:
#             return "ABCD est un parallélogramme."
#     else:
#         return "ABCD n'est pas un parallélogramme."
# </code></pre>
# </details>
