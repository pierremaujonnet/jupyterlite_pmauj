# %% [markdown]
# <style>
#     summary{
#         color:purple;
#         cursor:pointer;
#         font-weight:bold;
#     }
# </style>

# %% [markdown]
# ## Chaînes de caractères et listes

# %% [markdown]
# **Exercice :** Compléter la fonction suivante comptant le nombres de caractères égaux à "o" ou à "!" dans une chaîne de caractères.

# %%
def compte_caracteres(chaine):
    nbre = ...
    for caractere in chaine:
        if caractere == "o" ... caractere == "!":
            nbre ...
    return nbre

print(compte_caracteres("Bonjour à tous !"))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def compte_caracteres(chaine):
#     nbre = 0
#     for caractere in chaine:
#         if caractere == "o" or caractere == "!":
#             nbre += 1
#     return nbre
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Compléter la fonction suivante renvoyant le mot initial pour lequel :
# - chaque lettre "o" est remplacée par "e" ;
# - chaque lettre "E" est remplacée par "O" ;
# - tout autre lettre  est remplacée par "x".

# %%
def change_lettres(mot):
    nouveau_mot = ""
    for ... :
        if lettre == ...:
            nouveau_mot += "e"
        elif lettre == ...:
            nouveau_mot += ...
        else:
            nouveau_mot += ...
    return nouveau_mot

print(change_lettres("Encore"))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def change_lettres(mot):
#     nouveau_mot = ""
#     for lettre in mot:
#         if lettre == "o":
#             nouveau_mot += "e"
#         elif lettre == "E":
#             nouveau_mot += "O"
#         else:
#             nouveau_mot += "x"
#     return nouveau_mot
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Compléter la fonction suivante affichant chaque première lettre des prénoms d'une liste de prénoms.

# %%
def premieres_lettres(liste):
    for ...
    
premieres_lettres(["Léo", "Alphonse", "Paul", "Enora"])

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def premieres_lettres(liste):
#     for prenom in liste:
#         print(prenom[0])
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Compléter la fonction suivante renvoyant la somme des nombres divisibles par 4 dans une liste d'entiers naturels.

# %%
def somme_entiers(liste):
    somme = ...
    for n in liste:
        if ...:
            ...
    return ...

print(somme_entiers([1, 5, 8, 3, 16, 32, 120, 251, 22, 44, 67]))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def somme_entiers(liste):
#     somme = 0
#     for n in liste:
#         if n%4 == 0:
#             somme += n
#     return somme
# </code></pre>
# </details>

# %% [markdown]
# ## Utilisation de `range`

# %% [markdown]
# **Exercice :** Ecrire une fonction affichant la liste des cubes d'entiers consécutifs allant de $2^3$ à $15^3$ compris.

# %%
def cubes():
    ...
    

cubes()

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def cubes():
#     for i in range(2, 16):
#         print(i**3)
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** Chaque année un capital $C$ augmente de 3% par an. Ecrire une fonction renvoyant le capital obtenu après $n$ années.

# %%
def capital_obtenu(C, n):
    capital = ...
    ...

print(capital_obtenu(1000, 10))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def capital_obtenu(C, n):
#     capital = C
#     for i in range(n):
#         capital = capital*1.03
#     return capital
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** On lance un dé équilibré 12000 fois. Ecrire une fonction modélisant cette expérience aléatoire et renvoyant le nombre de fois où la face "6" a été obtenue.

# %%
from random import randint

def nombre_6():
    nbre = ...
    for ...:
        if ...:
            ...
    ...

print(nombre_6())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def nombre_6():
#     nbre = 0
#     for _ in range(12000):
#         if randint(1, 6) == 6:
#             nbre += 1
#     return nbre
# </code></pre>
# </details>

# %% [markdown]
# ## Boucle `while`

# %% [markdown]
# **Exercice :** Chaque année un capital $C$ augmente de 3% par an. Ecrire une fonction renvoyant le nombre d'années néccessaires pour voir le capital au moins triplé.

# %%
def nbre_annees(C):
    capital = ...
    n = ...
    while ...:
        capital ...
        n ...
    return ...

print(nbre_annees(1000))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def nbre_annees(C):
#     capital = C
#     n = 0
#     while capital < 3*C:
#         capital *= 1.03
#         n += 1
#     return n
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :** On lance un dé équilibré jusqu'à avoir obtenu 1000 fois la face "6" exactement. Ecrire une fonction renvoyant le nombre de lancers nécessaires.

# %%
from random import randint

def nombre_lancers():
    nbre_6 = ...
    nbre_l = ...
    ...
    

print(nombre_lancers())

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def nombre_lancers():
#     nbre_6 = 0
#     nbre_l = 0
#     while nbre_6 < 1000:
#         nbre_l +=1
#         if randint(1, 6) == 6:
#             nbre_6 += 1
#     return nbre_l
# </code></pre>
# </details>

# %% [markdown]
# ## Sommes

# %% [markdown]
# **Exercice :**
# 1. Ecrire une fonction renvoyant $1+2+4+8+\cdots+2^n$, $n$ étant donné, en utilisant une boucle `for`.
# 2. Faire de même en utilisant une boucle `while`.
# 3. Faire de même en utilisant une fonction récursive.

# %%
def somme_for(n):
    ...
    

def somme_while(n):
    ...
    

def somme_rec(n):
    ...
    

print(somme_for(10))
print(somme_while(10))
print(somme_rec(10))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def somme_for(n):
#     somme = 0
#     for i in range(n+1):
#         somme += 2**i
#     return somme
#
# def somme_while(n):
#     somme = 1
#     i = 0
#     while i < n:
#         i += 1
#         somme += 2**i
#     return somme
#
# def somme_rec(n):
#     if n == 0:
#         return 1
#     else:
#         return somme_rec(n-1) + 2**n
# </code></pre>
# </details>

# %% [markdown]
# **Exercice :**
# 1. Ecrire une fonction renvoyant la plus petite valeur entière $n$ telle que $1^3+2^3+3^3+4^3+\cdots+n^3\geq 10^8$.
# 2. Ecrire une fonction renvoyant $1^k+2^k+3^k+4^k+\cdots+n^k$, $n$ et $k$ étant deux entiers naturels donnés, en utilisant une boucle `for`.

# %%
def seuil_somme():
    ...
    

def somme_n_k(n, k):
    ...
    

print(seuil_somme())
print(somme_n_k(7, 5))

# %% [markdown]
# <details>
# <summary>Cliquer pour voir la solution</summary>
#
# <pre><code>def seuil_somme():
#     somme = 1
#     n = 1
#     while somme < 10**8:
#         n += 1
#         somme += n**3
#     return n
#
#
# def somme_n_k(n, k):
#     somme = 0
#     for i in range(n+1):
#         somme += i**k
#     return somme
# </code></pre>
# </details>
